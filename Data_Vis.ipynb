# %% [markdown]
# <a href="https://colab.research.google.com/github/Bakaos/Curso_UVV/blob/main/Data_Vis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <?xml version="1.0" encoding="UTF-8"?>
# <html>
#   <body>
#     <header></header>
#         <CENTER>
#           <img src="https://www.uvv.br/wp-content/themes/uvvBr/templates/assets//img/logouvv.svg" alt="UVV-LOGO" style = width="100px"; height="100px">
#         </CENTER>
#         <CENTER><b>Visualização de Dados</b></CENTER>
#         <CENTER><b>AOP2 - ATIVIDADE PONTUADA ONLINE</b></CENTER><br/>

# %% [markdown]
# NOME DO ALUNO: Hiran Alberto Hackbardt

# %% [markdown]
# Link para o Notebook: [**Notebook**](https://colab.research.google.com/drive/1wX2o9Y2fu3CL1QOajx2OOnSr2zt4WhIF?usp=sharing)

# %% [markdown]
# Prezado(a) aluno(a),
#
# Essa é uma atividade online pontuada do tipo "tarefa" e vale 2,0 pontos. O novo prazo limite para envio é de 15/08/2023 à 12/09/2023.
#
# Considerando o dataset das flores íris aqui. Pede-se:
#
# a) Qual (is) atributo(s) do dataset devem ser(em) apagado(s) pois não influenciam na classificação das flores? Explique a sua resposta.
# Uma vez que a classificação é feite com base das dimensões da pétala e da sépala a cidade de origem é irrelevante
#
# b) Qual comando Python deve ser utilizado para eliminar a(s) coluna(s)?
# o comando drop, nesse caso dt1.drop('cidade_origem', axis=1, inplace=True)
#
# c) Outro passo importante, é verificar se existem atributos com valores ausentes (NaN) na base de dados. Faça esta verificação usando comandos Python.
# o comando dt1.isna().sum() procura no dataset e faz uma totalização de todos os NaNs no set, neste caso temos 2 NaNs na coluna largura_sepala e 1 NaN na coluna comprimento_petala.
#
# Crie um notebook no Google Colab com a resolução destas questões. A entrega deve ser um arquivo txt ou pdf com o link do notebook compartilhado para
# eu fazer a correção.

# %%
import pandas as pd
from google.colab import drive
drive.mount ('/content/drive')
dt1 = pd.read_csv('/content/drive/MyDrive/iris_AP.csv')
dt1.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    id_planta  comprimento_sepala  largura_sepala  comprimento_petala  \
# 0          0                 5.1             3.5                 1.4
# 1          1                 4.9             3.0                 1.4
# 2          2                 4.7             3.2                 1.3
# 3          3                 4.6             3.1                 1.5
# 4          4                 5.0             3.6                 1.4
#
#    largura_petala cidade_origem       classe
# 0             0.2     São Paulo  Iris-setosa
# 1             0.2      Sorocaba  Iris-setosa
# 2             0.2     São Paulo  Iris-setosa
# 3             0.2      Sorocaba  Iris-setosa
# 4             0.2     São Paulo  Iris-setosa

# %%
dt1.drop('cidade_origem', axis=1, inplace=True)

# %%
dt1.head()
# Out:
#    id_planta  comprimento_sepala  largura_sepala  comprimento_petala  \
# 0          0                 5.1             3.5                 1.4
# 1          1                 4.9             3.0                 1.4
# 2          2                 4.7             3.2                 1.3
# 3          3                 4.6             3.1                 1.5
# 4          4                 5.0             3.6                 1.4
#
#    largura_petala       classe
# 0             0.2  Iris-setosa
# 1             0.2  Iris-setosa
# 2             0.2  Iris-setosa
# 3             0.2  Iris-setosa
# 4             0.2  Iris-setosa

# %%
print(dt1.isna().sum())
# Out:
# id_planta             0
# comprimento_sepala    0
# largura_sepala        2
# comprimento_petala    1
# largura_petala        0
# classe                0
# dtype: int64

# %%
# %%shell
# jupyter nbconvert --to html /content/AOP2_Hiran_Alberto_Hackbardt.ipynb
# Out:
# [NbConvertApp] Converting notebook /content/AOP2_Hiran_Alberto_Hackbardt.ipynb to html
# [NbConvertApp] Writing 598726 bytes to /content/AOP2_Hiran_Alberto_Hackbardt.html
